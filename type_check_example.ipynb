# %%
# Import Required Libraries
import requests
import json

# Fetch Data from Public API
url = "https://opentdb.com/api.php?amount=10"
response = requests.get(url)

# Parse JSON Data
parsed_data = response.json()

# Display the fetched trivia questions
for question in parsed_data['results']:
    print(f"Category: {question['category']}")
    print(f"Type: {question['type']}")
    print(f"Difficulty: {question['difficulty']}")
    print(f"Question: {question['question']}")
    print(f"Correct Answer: {question['correct_answer']}")
    print(f"Incorrect Answers: {question['incorrect_answers']}")
    print("\n")

# Process Data with Conditional List Comprehension
# Extract questions that contain the string 'the'
filtered_questions = [question['question'] for question in parsed_data['results'] if 'the' in question['question']]

# Display Filtered Questions with f-Strings
for title in filtered_questions:
    print(f"Filtered Question: {title}")

# Type Checking
# Check if one of the extracted titles is of type int
for title in filtered_questions:
    if isinstance(title, int):
        print(f"The title '{title}' is of type int.")
    else:
        print(f"The title '{title}' is of type {type(title).__name__}.")
# Out:
# Category: Science &amp; Nature
# Type: multiple
# Difficulty: hard
# Question: What is the scientific name of the red fox?
# Correct Answer: Vulpes Vulpes
# Incorrect Answers: ['Vulpes Redus', 'Red Fox', 'Vulpes Vulpie']
#
#
# Category: Entertainment: Video Games
# Type: multiple
# Difficulty: easy
# Question: Which of these is NOT a playable character in &quot;Left 4 Dead&quot;?
# Correct Answer: Nick
# Incorrect Answers: ['Louis', 'Zoey', 'Bill']
#
#
# Category: Science &amp; Nature
# Type: multiple
# Difficulty: easy
# Question: Human cells typically have how many copies of each gene?
# Correct Answer: 2
# Incorrect Answers: ['1', '4', '3']
#
#
# Category: History
# Type: boolean
# Difficulty: easy
# Question: The United States of America was the first country to launch a man into space.
# Correct Answer: False
# Incorrect Answers: ['True']
#
#
# Category: Entertainment: Video Games
# Type: multiple
# Difficulty: easy
# Question: In &quot;Undertale&quot;, how many main endings are there?
# Correct Answer: 3
# Incorrect Answers: ['2', '5', '13']
#
#
# Category: Animals
# Type: multiple
# Difficulty: hard
# Question: What is the scientific name of the cheetah?
# Correct Answer: Acinonyx jubatus
# Incorrect Answers: ['Panthera onca', 'Lynx rufus', 'Felis catus']
#
#
# Category: Entertainment: Cartoon &amp; Animations
# Type: multiple
# Difficulty: medium
# Question: Which one of these cartoon characters is NOT voiced by Rob Paulsen?
# Correct Answer: Max Tennyson (Ben 10)
# Incorrect Answers: ['Carl Wheezer (Jimmy Neutron)', 'Yakko Warner (Animaniacs)', 'The Mask (The Mask, TV Series)']
#
#
# Category: Entertainment: Video Games
# Type: multiple
# Difficulty: medium
# Question: When was Nintendo&#039;s Virtual Boy released?
# Correct Answer: 1995
# Incorrect Answers: ['1989', '1997', '1992']
#
#
# Category: Science &amp; Nature
# Type: multiple
# Difficulty: medium
# Question: What is the chemical formula for ammonia?
# Correct Answer: NH3
# Incorrect Answers: ['CO2', 'NO3', 'CH4']
#
#
# Category: Entertainment: Music
# Type: multiple
# Difficulty: easy
# Question: Which former boy-band star released hit solo single &quot;Angels&quot; in 1997?
# Correct Answer: Robbie Williams
# Incorrect Answers: ['Justin Timberlake', 'Harry Styles', 'Gary Barlow']
#
#
# Filtered Question: What is the scientific name of the red fox?
# Filtered Question: Which of these is NOT a playable character in &quot;Left 4 Dead&quot;?
# Filtered Question: The United States of America was the first country to launch a man into space.
# Filtered Question: In &quot;Undertale&quot;, how many main endings are there?
# Filtered Question: What is the scientific name of the cheetah?
# Filtered Question: Which one of these cartoon characters is NOT voiced by Rob Paulsen?
# Filtered Question: What is the chemical formula for ammonia?
# The title 'What is the scientific name of the red fox?' is of type str.
# The title 'Which of these is NOT a playable character in &quot;Left 4 Dead&quot;?' is of type str.
# The title 'The United States of America was the first country to launch a man into space.' is of type str.
# The title 'In &quot;Undertale&quot;, how many main endings are there?' is of type str.
# The title 'What is the scientific name of the cheetah?' is of type str.
# The title 'Which one of these cartoon characters is NOT voiced by Rob Paulsen?' is of type str.
# The title 'What is the chemical formula for ammonia?' is of type str.
